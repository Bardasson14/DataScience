# %% [markdown]
# <a href="https://colab.research.google.com/github/Bardasson14/DataScience/blob/master/Exerc%C3%ADcios_Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
sns.set_style('whitegrid')
sns.set_palette(sns.color_palette("Accent"))

# %%
url = 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'
titanic = pd.read_csv(url)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
del titanic['PassengerId']

# %%
titanic.head()
# Out:
#    Survived  Pclass  ... Cabin Embarked
# 0         0       3  ...   NaN        S
# 1         1       1  ...   C85        C
# 2         1       3  ...   NaN        S
# 3         1       1  ...  C123        S
# 4         0       3  ...   NaN        S
#
# [5 rows x 11 columns]

# %%
sns.jointplot(x = "Fare", y = "Age", data=titanic)

# %%
sns.distplot(titanic['Fare'], kde=False, color='red')
plt.xlim(0,500)
# Out:
# (0, 500)

# %%
sns.boxplot(x='Pclass', y='Age', data=titanic, palette=sns.color_palette("pastel"))

# %%
sns.swarmplot(x='Pclass', y='Age', data=titanic)

# %%
sns.countplot(titanic['Sex'])

# %%
sns.heatmap(titanic.corr(), cmap="coolwarm")

# %%
fg = sns.FacetGrid(data=titanic, col="Sex")
fg = fg.map(plt.hist,"Age")
plt.xlim(left=0)
# Out:
# (0, 83.979)
